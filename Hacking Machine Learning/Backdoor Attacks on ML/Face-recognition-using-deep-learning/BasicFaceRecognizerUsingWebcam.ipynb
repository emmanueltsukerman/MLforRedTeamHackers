# %% [markdown]
# # Basic face recognizer using pre trained model
#
# Below the is the implementation of a very basic face recognizer which can identify the face of the person showing on a web cam.
# The implementation is inspired by two path breaking papers on facial recognition using deep convoluted neural network, namely FaceNet and DeepFace.
#
# I have used pre trained model Keras-OpenFace which is an open source Keras implementation of the OpenFace (Originally Torch implemented)
#
# The pretrained model that I have used is by Victor Sy Wang's implementation and was loaded using his code: https://github.com/iwantooxxoox/Keras-OpenFace.

# %% [markdown]
# # Import the prerequisite libraries
#
# We will be importing utils.py from https://github.com/iwantooxxoox/Keras-OpenFace/blob/master/utils.py (available with code) which contains utility functions to create the neural network and load the weights assoiated with it.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from keras.models import Model
from keras.layers.normalization import BatchNormalization
from keras.layers.pooling import MaxPooling2D, AveragePooling2D
from keras.layers.merge import Concatenate
from keras.layers.core import Lambda, Flatten, Dense
from keras.engine.topology import Layer
from keras import backend as K
import cv2
import os
import sys
import numpy as np
from numpy import genfromtxt
import pandas as pd
import tensorflow as tf
from utils import LRN2D
import utils

# %load_ext autoreload
# %autoreload 2

np.set_printoptions(threshold=sys.maxsize)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Contructing the neural network model
# The model here constructed is based on FaceNet's Inception model.
#
# The implementation of model is available at: https://github.com/iwantooxxoox/Keras-OpenFace

# %%
myInput = Input(shape=(96, 96, 3))

x = ZeroPadding2D(padding=(3, 3), input_shape=(96, 96, 3))(myInput)
x = Conv2D(64, (7, 7), strides=(2, 2), name='conv1')(x)
x = BatchNormalization(axis=3, epsilon=0.00001, name='bn1')(x)
x = Activation('relu')(x)
x = ZeroPadding2D(padding=(1, 1))(x)
x = MaxPooling2D(pool_size=3, strides=2)(x)
x = Lambda(LRN2D, name='lrn_1')(x)
x = Conv2D(64, (1, 1), name='conv2')(x)
x = BatchNormalization(axis=3, epsilon=0.00001, name='bn2')(x)
x = Activation('relu')(x)
x = ZeroPadding2D(padding=(1, 1))(x)
x = Conv2D(192, (3, 3), name='conv3')(x)
x = BatchNormalization(axis=3, epsilon=0.00001, name='bn3')(x)
x = Activation('relu')(x)
x = Lambda(LRN2D, name='lrn_2')(x)
x = ZeroPadding2D(padding=(1, 1))(x)
x = MaxPooling2D(pool_size=3, strides=2)(x)

# Inception3a
inception_3a_3x3 = Conv2D(96, (1, 1), name='inception_3a_3x3_conv1')(x)
inception_3a_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_3x3_bn1')(inception_3a_3x3)
inception_3a_3x3 = Activation('relu')(inception_3a_3x3)
inception_3a_3x3 = ZeroPadding2D(padding=(1, 1))(inception_3a_3x3)
inception_3a_3x3 = Conv2D(128, (3, 3), name='inception_3a_3x3_conv2')(inception_3a_3x3)
inception_3a_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_3x3_bn2')(inception_3a_3x3)
inception_3a_3x3 = Activation('relu')(inception_3a_3x3)

inception_3a_5x5 = Conv2D(16, (1, 1), name='inception_3a_5x5_conv1')(x)
inception_3a_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_5x5_bn1')(inception_3a_5x5)
inception_3a_5x5 = Activation('relu')(inception_3a_5x5)
inception_3a_5x5 = ZeroPadding2D(padding=(2, 2))(inception_3a_5x5)
inception_3a_5x5 = Conv2D(32, (5, 5), name='inception_3a_5x5_conv2')(inception_3a_5x5)
inception_3a_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_5x5_bn2')(inception_3a_5x5)
inception_3a_5x5 = Activation('relu')(inception_3a_5x5)

inception_3a_pool = MaxPooling2D(pool_size=3, strides=2)(x)
inception_3a_pool = Conv2D(32, (1, 1), name='inception_3a_pool_conv')(inception_3a_pool)
inception_3a_pool = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_pool_bn')(inception_3a_pool)
inception_3a_pool = Activation('relu')(inception_3a_pool)
inception_3a_pool = ZeroPadding2D(padding=((3, 4), (3, 4)))(inception_3a_pool)

inception_3a_1x1 = Conv2D(64, (1, 1), name='inception_3a_1x1_conv')(x)
inception_3a_1x1 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_1x1_bn')(inception_3a_1x1)
inception_3a_1x1 = Activation('relu')(inception_3a_1x1)

inception_3a = concatenate([inception_3a_3x3, inception_3a_5x5, inception_3a_pool, inception_3a_1x1], axis=3)

# Inception3b
inception_3b_3x3 = Conv2D(96, (1, 1), name='inception_3b_3x3_conv1')(inception_3a)
inception_3b_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_3x3_bn1')(inception_3b_3x3)
inception_3b_3x3 = Activation('relu')(inception_3b_3x3)
inception_3b_3x3 = ZeroPadding2D(padding=(1, 1))(inception_3b_3x3)
inception_3b_3x3 = Conv2D(128, (3, 3), name='inception_3b_3x3_conv2')(inception_3b_3x3)
inception_3b_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_3x3_bn2')(inception_3b_3x3)
inception_3b_3x3 = Activation('relu')(inception_3b_3x3)

inception_3b_5x5 = Conv2D(32, (1, 1), name='inception_3b_5x5_conv1')(inception_3a)
inception_3b_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_5x5_bn1')(inception_3b_5x5)
inception_3b_5x5 = Activation('relu')(inception_3b_5x5)
inception_3b_5x5 = ZeroPadding2D(padding=(2, 2))(inception_3b_5x5)
inception_3b_5x5 = Conv2D(64, (5, 5), name='inception_3b_5x5_conv2')(inception_3b_5x5)
inception_3b_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_5x5_bn2')(inception_3b_5x5)
inception_3b_5x5 = Activation('relu')(inception_3b_5x5)

inception_3b_pool = Lambda(lambda x: x**2, name='power2_3b')(inception_3a)
inception_3b_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_3b_pool)
inception_3b_pool = Lambda(lambda x: x*9, name='mult9_3b')(inception_3b_pool)
inception_3b_pool = Lambda(lambda x: K.sqrt(x), name='sqrt_3b')(inception_3b_pool)
inception_3b_pool = Conv2D(64, (1, 1), name='inception_3b_pool_conv')(inception_3b_pool)
inception_3b_pool = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_pool_bn')(inception_3b_pool)
inception_3b_pool = Activation('relu')(inception_3b_pool)
inception_3b_pool = ZeroPadding2D(padding=(4, 4))(inception_3b_pool)

inception_3b_1x1 = Conv2D(64, (1, 1), name='inception_3b_1x1_conv')(inception_3a)
inception_3b_1x1 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_1x1_bn')(inception_3b_1x1)
inception_3b_1x1 = Activation('relu')(inception_3b_1x1)

inception_3b = concatenate([inception_3b_3x3, inception_3b_5x5, inception_3b_pool, inception_3b_1x1], axis=3)

# Inception3c
inception_3c_3x3 = utils.conv2d_bn(inception_3b,
                                   layer='inception_3c_3x3',
                                   cv1_out=128,
                                   cv1_filter=(1, 1),
                                   cv2_out=256,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(2, 2),
                                   padding=(1, 1))

inception_3c_5x5 = utils.conv2d_bn(inception_3b,
                                   layer='inception_3c_5x5',
                                   cv1_out=32,
                                   cv1_filter=(1, 1),
                                   cv2_out=64,
                                   cv2_filter=(5, 5),
                                   cv2_strides=(2, 2),
                                   padding=(2, 2))

inception_3c_pool = MaxPooling2D(pool_size=3, strides=2)(inception_3b)
inception_3c_pool = ZeroPadding2D(padding=((0, 1), (0, 1)))(inception_3c_pool)

inception_3c = concatenate([inception_3c_3x3, inception_3c_5x5, inception_3c_pool], axis=3)

#inception 4a
inception_4a_3x3 = utils.conv2d_bn(inception_3c,
                                   layer='inception_4a_3x3',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   cv2_out=192,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(1, 1),
                                   padding=(1, 1))
inception_4a_5x5 = utils.conv2d_bn(inception_3c,
                                   layer='inception_4a_5x5',
                                   cv1_out=32,
                                   cv1_filter=(1, 1),
                                   cv2_out=64,
                                   cv2_filter=(5, 5),
                                   cv2_strides=(1, 1),
                                   padding=(2, 2))

inception_4a_pool = Lambda(lambda x: x**2, name='power2_4a')(inception_3c)
inception_4a_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_4a_pool)
inception_4a_pool = Lambda(lambda x: x*9, name='mult9_4a')(inception_4a_pool)
inception_4a_pool = Lambda(lambda x: K.sqrt(x), name='sqrt_4a')(inception_4a_pool)
inception_4a_pool = utils.conv2d_bn(inception_4a_pool,
                                   layer='inception_4a_pool',
                                   cv1_out=128,
                                   cv1_filter=(1, 1),
                                   padding=(2, 2))
inception_4a_1x1 = utils.conv2d_bn(inception_3c,
                                   layer='inception_4a_1x1',
                                   cv1_out=256,
                                   cv1_filter=(1, 1))
inception_4a = concatenate([inception_4a_3x3, inception_4a_5x5, inception_4a_pool, inception_4a_1x1], axis=3)

#inception4e
inception_4e_3x3 = utils.conv2d_bn(inception_4a,
                                   layer='inception_4e_3x3',
                                   cv1_out=160,
                                   cv1_filter=(1, 1),
                                   cv2_out=256,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(2, 2),
                                   padding=(1, 1))
inception_4e_5x5 = utils.conv2d_bn(inception_4a,
                                   layer='inception_4e_5x5',
                                   cv1_out=64,
                                   cv1_filter=(1, 1),
                                   cv2_out=128,
                                   cv2_filter=(5, 5),
                                   cv2_strides=(2, 2),
                                   padding=(2, 2))
inception_4e_pool = MaxPooling2D(pool_size=3, strides=2)(inception_4a)
inception_4e_pool = ZeroPadding2D(padding=((0, 1), (0, 1)))(inception_4e_pool)

inception_4e = concatenate([inception_4e_3x3, inception_4e_5x5, inception_4e_pool], axis=3)

#inception5a
inception_5a_3x3 = utils.conv2d_bn(inception_4e,
                                   layer='inception_5a_3x3',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   cv2_out=384,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(1, 1),
                                   padding=(1, 1))

inception_5a_pool = Lambda(lambda x: x**2, name='power2_5a')(inception_4e)
inception_5a_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_5a_pool)
inception_5a_pool = Lambda(lambda x: x*9, name='mult9_5a')(inception_5a_pool)
inception_5a_pool = Lambda(lambda x: K.sqrt(x), name='sqrt_5a')(inception_5a_pool)
inception_5a_pool = utils.conv2d_bn(inception_5a_pool,
                                   layer='inception_5a_pool',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   padding=(1, 1))
inception_5a_1x1 = utils.conv2d_bn(inception_4e,
                                   layer='inception_5a_1x1',
                                   cv1_out=256,
                                   cv1_filter=(1, 1))

inception_5a = concatenate([inception_5a_3x3, inception_5a_pool, inception_5a_1x1], axis=3)

#inception_5b
inception_5b_3x3 = utils.conv2d_bn(inception_5a,
                                   layer='inception_5b_3x3',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   cv2_out=384,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(1, 1),
                                   padding=(1, 1))
inception_5b_pool = MaxPooling2D(pool_size=3, strides=2)(inception_5a)
inception_5b_pool = utils.conv2d_bn(inception_5b_pool,
                                   layer='inception_5b_pool',
                                   cv1_out=96,
                                   cv1_filter=(1, 1))
inception_5b_pool = ZeroPadding2D(padding=(1, 1))(inception_5b_pool)

inception_5b_1x1 = utils.conv2d_bn(inception_5a,
                                   layer='inception_5b_1x1',
                                   cv1_out=256,
                                   cv1_filter=(1, 1))
inception_5b = concatenate([inception_5b_3x3, inception_5b_pool, inception_5b_1x1], axis=3)

av_pool = AveragePooling2D(pool_size=(3, 3), strides=(1, 1))(inception_5b)
reshape_layer = Flatten()(av_pool)
dense_layer = Dense(128, name='dense_layer')(reshape_layer)
norm_layer = Lambda(lambda  x: K.l2_normalize(x, axis=1), name='norm_layer')(dense_layer)


# Final Model
model = Model(inputs=[myInput], outputs=norm_layer)

# %% [markdown]
# # Loading the model with pretrained weights
#
# FaceNet is trained by minimizing the triplet loss. I will be  loading a previously trained model. weights are avaiable at https://github.com/iwantooxxoox/Keras-OpenFace in the "weights" folder which is also provided in this source.
#
# This can take a couple of minutes to execute and depends on the speed of your machine.

# %%
# Load weights from csv files (which was exported from Openface torch model)
weights = utils.weights
weights_dict = utils.load_weights()

# Set layer weights of the model
for name in weights:
  if model.get_layer(name) != None:
    model.get_layer(name).set_weights(weights_dict[name])
  elif model.get_layer(name) != None:
    model.get_layer(name).set_weights(weights_dict[name])

# %% [markdown]
# ## About <font color=blue>image_to_embedding</font> function
# When the model is loaded with pre trained weights, then we can create the **128 dimensional embedding vectors** for all the face images stored in the "images" folder. **"image_to_embedding"** function pass an image to the Inception network to generate the embedding vector.

# %%
def image_to_embedding(image, model):
    #image = cv2.resize(image, (96, 96), interpolation=cv2.INTER_AREA) 
    image = cv2.resize(image, (96, 96)) 
    img = image[...,::-1]
    img = np.around(np.transpose(img, (0,1,2))/255.0, decimals=12)
    x_train = np.array([img])
    embedding = model.predict_on_batch(x_train)
    return embedding

# %% [markdown]
# ## About <font color=blue>recognize_face</font> function
# This function calculate similarity between the captured image and the images that are already been stored. It passes the image to the trained neural network to generate its embedding vector. Which is then compared with all the embedding vectors of the images stored by calculating L2 Euclidean distance.
#
# If the minimum L2 distance between two embeddings is less than a threshpld (here I have taken the threashhold as .68 (which can be adjusted) then we have a match.

# %%
def recognize_face(face_image, input_embeddings, model):

    embedding = image_to_embedding(face_image, model)
    
    minimum_distance = 200
    name = None
    
    # Loop over  names and encodings.
    for (input_name, input_embedding) in input_embeddings.items():
        
       
        euclidean_distance = np.linalg.norm(embedding-input_embedding)
        

        print('Euclidean distance from %s is %s' %(input_name, euclidean_distance))

        
        if euclidean_distance < minimum_distance:
            minimum_distance = euclidean_distance
            name = input_name
    
    if minimum_distance < 0.68:
        return str(name)
    else:
        return None

# %% [markdown]
# ## About <font color=blue>create_input_image_embeddings</font> function
# This function generates 128 dimensional image ebeddings of all the images stored in the "images" directory by feed forwarding the images to a trained neural network. It creates a dictionary with key as the name of the face and value as embedding
#
#
# ## About <font color=blue>recognize_faces_in_cam</font> function
# This function capture image from the webcam, detect a face in it and crop the image to have a face only, which is then passed to recognize_face function.

# %%
import glob

def create_input_image_embeddings():
    input_embeddings = {}

    for file in glob.glob("images/*"):
        person_name = os.path.splitext(os.path.basename(file))[0]
        image_file = cv2.imread(file, 1)
        input_embeddings[person_name] = image_to_embedding(image_file, model)

    return input_embeddings

def recognize_faces_in_cam(input_embeddings):
    

    cv2.namedWindow("Face Recognizer")
    vc = cv2.VideoCapture(0)
   

    font = cv2.FONT_HERSHEY_SIMPLEX
    face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    
    
    while vc.isOpened():
        _, frame = vc.read()
        img = frame
        height, width, channels = frame.shape

        
        
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)

        # Loop through all the faces detected 
        identities = []
        for (x, y, w, h) in faces:
            x1 = x
            y1 = y
            x2 = x+w
            y2 = y+h

           
            
            face_image = frame[max(0, y1):min(height, y2), max(0, x1):min(width, x2)]    
            identity = recognize_face(face_image, input_embeddings, model)
            
            

            if identity is not None:
                img = cv2.rectangle(frame,(x1, y1),(x2, y2),(255,255,255),2)
                cv2.putText(img, str(identity), (x1+5,y1-5), font, 1, (255,255,255), 2)
        
        key = cv2.waitKey(100)
        cv2.imshow("Face Recognizer", img)

        if key == 27: # exit on ESC
            break
    vc.release()
    cv2.destroyAllWindows()

# %% [markdown]
# ## Capturing the face image
# Following code captures 1 face image of the person. It is stored in **"images"** folder with the name User_1. Rename it with the name of person and delete rest of them. This image will be used for recognizing the the identity of the person using one shot learning.

# %%
cam = cv2.VideoCapture(0)

face_detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

num_images = 1
count = 0
while(True):
    ret, img = cam.read()
    #gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_detector.detectMultiScale(img, 1.3, 5)
    for (x,y,w,h) in faces:
        x1 = x
        y1 = y
        x2 = x+w
        y2 = y+h
        cv2.rectangle(img, (x1,y1), (x2,y2), (255,255,255), 2)     
        count += 1
        # Save the captured image into the datasets folder
        cv2.imwrite("images/User_" + str(count) + ".jpg", img[y1:y2,x1:x2])
        cv2.imshow('image', img)
    k = cv2.waitKey(200) & 0xff # Press 'ESC' for exiting video
    if k == 27:
        break
    elif count >= num_images:
         break
cam.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Lets run the face recognizer program :-)

# %%
input_embeddings = create_input_image_embeddings()
recognize_faces_in_cam(input_embeddings)
# Out:
# Euclidean distance from Kunal is 0.9871731
# Euclidean distance from Normal User is 0.5516295
# Euclidean distance from Root is 0.7043868
# Euclidean distance from Sumantra is 0.98603076
# Euclidean distance from Kunal is 1.0113516
# Euclidean distance from Normal User is 0.5454924
# Euclidean distance from Root is 0.7243677
# Euclidean distance from Sumantra is 0.9972819
# Euclidean distance from Kunal is 1.0983428
# Euclidean distance from Normal User is 0.5909114
# Euclidean distance from Root is 0.73019195
# Euclidean distance from Sumantra is 0.9992552
# Euclidean distance from Kunal is 1.2035899
# Euclidean distance from Normal User is 0.7026558
# Euclidean distance from Root is 0.77170557
# Euclidean distance from Sumantra is 1.0133264
# Euclidean distance from Kunal is 1.0848299
# Euclidean distance from Normal User is 0.7035553
# Euclidean distance from Root is 0.7297131
# Euclidean distance from Sumantra is 1.0416954
# Euclidean distance from Kunal is 1.0109756
# Euclidean distance from Normal User is 0.6380882
# Euclidean distance from Root is 0.78140765
# Euclidean distance from Sumantra is 0.9960658
# Euclidean distance from Kunal is 1.1367877
# Euclidean distance from Normal User is 0.6822866
# Euclidean distance from Root is 0.812093
# Euclidean distance from Sumantra is 1.0060666
# Euclidean distance from Kunal is 1.057038
# Euclidean distance from Normal User is 0.7694672
# Euclidean distance from Root is 0.94840837
# Euclidean distance from Sumantra is 0.8450547
# Euclidean distance from Kunal is 1.0889252
# Euclidean distance from Normal User is 0.69265807
# Euclidean distance from Root is 0.7250079
# Euclidean distance from Sumantra is 1.1109755
# Euclidean distance from Kunal is 1.0182207
# Euclidean distance from Normal User is 0.69199866
# Euclidean distance from Root is 0.85427076
# Euclidean distance from Sumantra is 0.89569074
# Euclidean distance from Kunal is 1.1543056
# Euclidean distance from Normal User is 0.8427772
# Euclidean distance from Root is 0.94294506
# Euclidean distance from Sumantra is 0.8819002
# Euclidean distance from Kunal is 1.1163925
# Euclidean distance from Normal User is 0.6047155
# Euclidean distance from Root is 0.79879373
# Euclidean distance from Sumantra is 0.9082342
# Euclidean distance from Kunal is 1.0683187
# Euclidean distance from Normal User is 0.7113465
# Euclidean distance from Root is 0.79967993
# Euclidean distance from Sumantra is 1.0043964
# Euclidean distance from Kunal is 1.0457631
# Euclidean distance from Normal User is 0.6256774
# Euclidean distance from Root is 0.7491887
# Euclidean distance from Sumantra is 0.92664266
# Euclidean distance from Kunal is 1.0840563
# Euclidean distance from Normal User is 0.6498171
# Euclidean distance from Root is 0.80728716
# Euclidean distance from Sumantra is 0.9572812
# Euclidean distance from Kunal is 1.0803713
# Euclidean distance from Normal User is 0.7199663
# Euclidean distance from Root is 0.8279738
# Euclidean distance from Sumantra is 1.0264963
# Euclidean distance from Kunal is 1.258789
# Euclidean distance from Normal User is 0.72085637
# Euclidean distance from Root is 0.69073
# Euclidean distance from Sumantra is 1.1561192
# Euclidean distance from Kunal is 1.1563178
# Euclidean distance from Normal User is 0.7090038
# Euclidean distance from Root is 0.83260185
# Euclidean distance from Sumantra is 0.9423677
# Euclidean distance from Kunal is 1.1775454
# Euclidean distance from Normal User is 0.7753787
# Euclidean distance from Root is 0.92704326
# Euclidean distance from Sumantra is 0.92358726
# Euclidean distance from Kunal is 1.1996858
# Euclidean distance from Normal User is 0.7986011
# Euclidean distance from Root is 0.87679666
# Euclidean distance from Sumantra is 0.9619143
# Euclidean distance from Kunal is 1.0352528
# Euclidean distance from Normal User is 0.68499064
# Euclidean distance from Root is 0.86468273
# Euclidean distance from Sumantra is 0.9920454
# Euclidean distance from Kunal is 1.1643566
# Euclidean distance from Normal User is 0.7870677
# Euclidean distance from Root is 0.90218204
# Euclidean distance from Sumantra is 0.9780947
# Euclidean distance from Kunal is 1.0870961
# Euclidean distance from Normal User is 0.83382446
# Euclidean distance from Root is 0.9321468
# Euclidean distance from Sumantra is 0.92903274
# Euclidean distance from Kunal is 1.0706923
# Euclidean distance from Normal User is 0.7046636
# Euclidean distance from Root is 0.8166782
# Euclidean distance from Sumantra is 1.0374929
# Euclidean distance from Kunal is 1.1114591
# Euclidean distance from Normal User is 0.74205196
# Euclidean distance from Root is 0.89187
# Euclidean distance from Sumantra is 0.9303178
# Euclidean distance from Kunal is 1.1170975
# Euclidean distance from Normal User is 0.79956955
# Euclidean distance from Root is 0.9436064
# Euclidean distance from Sumantra is 0.9136131
# Euclidean distance from Kunal is 1.0979415
# Euclidean distance from Normal User is 0.7234649
# Euclidean distance from Root is 0.87201655
# Euclidean distance from Sumantra is 1.0258565
# Euclidean distance from Kunal is 1.071414
# Euclidean distance from Normal User is 0.6996074
# Euclidean distance from Root is 0.7848106
# Euclidean distance from Sumantra is 0.97079223
# Euclidean distance from Kunal is 0.9968507
# Euclidean distance from Normal User is 0.7993907
# Euclidean distance from Root is 0.8960304
# Euclidean distance from Sumantra is 0.95743024
# Euclidean distance from Kunal is 1.028993
# Euclidean distance from Normal User is 0.6539266
# Euclidean distance from Root is 0.8190637
# Euclidean distance from Sumantra is 0.9149624
# Euclidean distance from Kunal is 1.0607868
# Euclidean distance from Normal User is 0.6450178
# Euclidean distance from Root is 0.7754077
# Euclidean distance from Sumantra is 0.95731646
# Euclidean distance from Kunal is 1.0192535
# Euclidean distance from Normal User is 0.5721164
# Euclidean distance from Root is 0.7718567
# Euclidean distance from Sumantra is 1.0023808
# Euclidean distance from Kunal is 1.2231727
# Euclidean distance from Normal User is 0.7115774
# Euclidean distance from Root is 0.73736036
# Euclidean distance from Sumantra is 1.0917788
# Euclidean distance from Kunal is 1.0005248
# Euclidean distance from Normal User is 0.6758355
# Euclidean distance from Root is 0.76415175
# Euclidean distance from Sumantra is 1.0596532
# Euclidean distance from Kunal is 0.9966952
# Euclidean distance from Normal User is 0.65466136
# Euclidean distance from Root is 0.73286045
# Euclidean distance from Sumantra is 1.0650377
# Euclidean distance from Kunal is 1.0732892
# Euclidean distance from Normal User is 0.7146934
# Euclidean distance from Root is 0.82340956
# Euclidean distance from Sumantra is 1.0916867
# Euclidean distance from Kunal is 1.0205644
# Euclidean distance from Normal User is 0.7014603
# Euclidean distance from Root is 0.8145116
# Euclidean distance from Sumantra is 1.0666687
# Euclidean distance from Kunal is 1.0335587
# Euclidean distance from Normal User is 0.68765056
# Euclidean distance from Root is 0.82607526
# Euclidean distance from Sumantra is 1.0545771
# Euclidean distance from Kunal is 1.0772283
# Euclidean distance from Normal User is 0.70040745
# Euclidean distance from Root is 0.7737527
# Euclidean distance from Sumantra is 1.0808192
# Euclidean distance from Kunal is 1.111195
# Euclidean distance from Normal User is 0.65588045
# Euclidean distance from Root is 0.7802862
# Euclidean distance from Sumantra is 1.0617439
# Euclidean distance from Kunal is 1.1294489
# Euclidean distance from Normal User is 0.586541
# Euclidean distance from Root is 0.6477117
# Euclidean distance from Sumantra is 1.1094987
# Euclidean distance from Kunal is 1.1510687
# Euclidean distance from Normal User is 0.72389966
# Euclidean distance from Root is 0.8554513
# Euclidean distance from Sumantra is 0.93261087
# Euclidean distance from Kunal is 1.1373907
# Euclidean distance from Normal User is 0.68698376
# Euclidean distance from Root is 0.80746573
# Euclidean distance from Sumantra is 0.93849885
# Euclidean distance from Kunal is 1.238896
# Euclidean distance from Normal User is 0.7436936
# Euclidean distance from Root is 0.8387767
# Euclidean distance from Sumantra is 0.9801221
# Euclidean distance from Kunal is 1.1540712
# Euclidean distance from Normal User is 0.6943938
# Euclidean distance from Root is 0.85603386
# Euclidean distance from Sumantra is 1.0073351
# Euclidean distance from Kunal is 1.084173
# Euclidean distance from Normal User is 0.78986055
# Euclidean distance from Root is 0.9339203
# Euclidean distance from Sumantra is 0.91781944
# Euclidean distance from Kunal is 0.97555876
# Euclidean distance from Normal User is 0.8378621
# Euclidean distance from Root is 0.8587564
# Euclidean distance from Sumantra is 0.9622729
# Euclidean distance from Kunal is 1.1438534
# Euclidean distance from Normal User is 0.77574724
# Euclidean distance from Root is 0.9116373
# Euclidean distance from Sumantra is 0.9618696
# Euclidean distance from Kunal is 1.0108739
# Euclidean distance from Normal User is 0.7741418
# Euclidean distance from Root is 0.86367184
# Euclidean distance from Sumantra is 0.98704743
# Euclidean distance from Kunal is 1.0366563
# Euclidean distance from Normal User is 0.76064503
# Euclidean distance from Root is 0.8947855
# Euclidean distance from Sumantra is 0.9404083
# Euclidean distance from Kunal is 1.0809999
# Euclidean distance from Normal User is 0.8113655
# Euclidean distance from Root is 0.90545285
# Euclidean distance from Sumantra is 0.96528494
# Euclidean distance from Kunal is 1.0952841
# Euclidean distance from Normal User is 0.78144383
# Euclidean distance from Root is 0.86743397
# Euclidean distance from Sumantra is 0.9554178
# Euclidean distance from Kunal is 1.0675504
# Euclidean distance from Normal User is 0.75611335
# Euclidean distance from Root is 0.8598938
# Euclidean distance from Sumantra is 1.0141307
# Euclidean distance from Kunal is 1.0426022
# Euclidean distance from Normal User is 0.79619235
# Euclidean distance from Root is 0.82207584
# Euclidean distance from Sumantra is 1.0404582
# Euclidean distance from Kunal is 1.0586798
# Euclidean distance from Normal User is 0.86540437
# Euclidean distance from Root is 0.91745615
# Euclidean distance from Sumantra is 0.9490106
# Euclidean distance from Kunal is 0.96551603
# Euclidean distance from Normal User is 0.8705197
# Euclidean distance from Root is 0.9372053
# Euclidean distance from Sumantra is 0.97421503
# Euclidean distance from Kunal is 1.0528681
# Euclidean distance from Normal User is 0.8146206
# Euclidean distance from Root is 0.94282526
# Euclidean distance from Sumantra is 0.9313301
# Euclidean distance from Kunal is 1.1024289
# Euclidean distance from Normal User is 0.7475494
# Euclidean distance from Root is 0.8248447
# Euclidean distance from Sumantra is 0.97101575
# Euclidean distance from Kunal is 1.0443115
# Euclidean distance from Normal User is 0.76931
# Euclidean distance from Root is 0.9016365
# Euclidean distance from Sumantra is 0.9650206
# Euclidean distance from Kunal is 1.0736213
# Euclidean distance from Normal User is 0.7815881
# Euclidean distance from Root is 0.86007303
# Euclidean distance from Sumantra is 0.9681918
# Euclidean distance from Kunal is 1.0341791
# Euclidean distance from Normal User is 0.8324679
# Euclidean distance from Root is 0.9735005
# Euclidean distance from Sumantra is 0.93991506
# Euclidean distance from Kunal is 0.9815445
# Euclidean distance from Normal User is 0.7196012
# Euclidean distance from Root is 0.8930487
# Euclidean distance from Sumantra is 0.90522826
# Euclidean distance from Kunal is 1.1121575
# Euclidean distance from Normal User is 0.774914
# Euclidean distance from Root is 0.8652307
# Euclidean distance from Sumantra is 0.94380474
# Euclidean distance from Kunal is 1.115952
# Euclidean distance from Normal User is 0.8073672
# Euclidean distance from Root is 0.871593
# Euclidean distance from Sumantra is 0.94746906
# Euclidean distance from Kunal is 0.9928157
# Euclidean distance from Normal User is 0.85660166
# Euclidean distance from Root is 0.98812455
# Euclidean distance from Sumantra is 0.8549024
# Euclidean distance from Kunal is 1.0717283
# Euclidean distance from Normal User is 0.8675143
# Euclidean distance from Root is 0.9638544
# Euclidean distance from Sumantra is 0.9352139
# Euclidean distance from Kunal is 1.264541
# Euclidean distance from Normal User is 0.6680914
# Euclidean distance from Root is 0.7507872
# Euclidean distance from Sumantra is 0.88878846
# Euclidean distance from Kunal is 1.0543536
# Euclidean distance from Normal User is 0.7268462
# Euclidean distance from Root is 0.79757833
# Euclidean distance from Sumantra is 0.8920433
# Euclidean distance from Kunal is 1.1322345
# Euclidean distance from Normal User is 0.6169268
# Euclidean distance from Root is 0.7600031
# Euclidean distance from Sumantra is 0.95765746
# Euclidean distance from Kunal is 1.2159444
# Euclidean distance from Normal User is 0.6947334
# Euclidean distance from Root is 0.62727904
# Euclidean distance from Sumantra is 1.0346186
# Euclidean distance from Kunal is 1.0451152
# Euclidean distance from Normal User is 0.62386805
# Euclidean distance from Root is 0.7106358
# Euclidean distance from Sumantra is 0.97263944
# Euclidean distance from Kunal is 1.0692421
# Euclidean distance from Normal User is 0.5825408
# Euclidean distance from Root is 0.7134426
# Euclidean distance from Sumantra is 0.9852872
# Euclidean distance from Kunal is 1.0401539
# Euclidean distance from Normal User is 0.60496217
# Euclidean distance from Root is 0.7354973
# Euclidean distance from Sumantra is 1.0302237
# Euclidean distance from Kunal is 0.9938377
# Euclidean distance from Normal User is 0.5752197
# Euclidean distance from Root is 0.74961567
# Euclidean distance from Sumantra is 0.9852761
# Euclidean distance from Kunal is 1.0051298
# Euclidean distance from Normal User is 0.7577763
# Euclidean distance from Root is 0.7323844
# Euclidean distance from Sumantra is 1.0390185
# Euclidean distance from Kunal is 0.96029985
# Euclidean distance from Normal User is 0.82860386
# Euclidean distance from Root is 0.7772469
# Euclidean distance from Sumantra is 1.0938066
# Euclidean distance from Kunal is 0.90368164
# Euclidean distance from Normal User is 0.8593925
# Euclidean distance from Root is 0.9378228
# Euclidean distance from Sumantra is 1.0344044
# Euclidean distance from Kunal is 1.0595857
# Euclidean distance from Normal User is 0.69927436
# Euclidean distance from Root is 0.83498573
# Euclidean distance from Sumantra is 0.9345915
# Euclidean distance from Kunal is 1.0480976
# Euclidean distance from Normal User is 0.62174845
# Euclidean distance from Root is 0.73696285
# Euclidean distance from Sumantra is 1.007041
# Euclidean distance from Kunal is 1.0057449
# Euclidean distance from Normal User is 0.58771783
# Euclidean distance from Root is 0.7368955
# Euclidean distance from Sumantra is 0.9958669
# Euclidean distance from Kunal is 0.987164
# Euclidean distance from Normal User is 0.6364813
# Euclidean distance from Root is 0.7903638
# Euclidean distance from Sumantra is 1.0532486
# Euclidean distance from Kunal is 0.9820522
# Euclidean distance from Normal User is 0.5827509
# Euclidean distance from Root is 0.74912834
# Euclidean distance from Sumantra is 1.0145969
# Euclidean distance from Kunal is 1.0509313
# Euclidean distance from Normal User is 0.5736989
# Euclidean distance from Root is 0.723389
# Euclidean distance from Sumantra is 0.95370257
# Euclidean distance from Kunal is 1.0344447
# Euclidean distance from Normal User is 0.60683775
# Euclidean distance from Root is 0.7341316
# Euclidean distance from Sumantra is 1.0453998
# Euclidean distance from Kunal is 1.0671195
# Euclidean distance from Normal User is 0.64525944
# Euclidean distance from Root is 0.8185044
# Euclidean distance from Sumantra is 1.0059752
# Euclidean distance from Kunal is 1.1347668
# Euclidean distance from Normal User is 0.64458454
# Euclidean distance from Root is 0.70177215
# Euclidean distance from Sumantra is 1.0407294
# Euclidean distance from Kunal is 1.1743561
# Euclidean distance from Normal User is 0.7469558
# Euclidean distance from Root is 0.78184134
# Euclidean distance from Sumantra is 1.074612
# Euclidean distance from Kunal is 0.885892
# Euclidean distance from Normal User is 0.7906314
# Euclidean distance from Root is 0.8872551
# Euclidean distance from Sumantra is 1.0407494
# Euclidean distance from Kunal is 1.0075545
# Euclidean distance from Normal User is 0.7395766
# Euclidean distance from Root is 0.76521313
# Euclidean distance from Sumantra is 1.0476283
# Euclidean distance from Kunal is 1.0451052
# Euclidean distance from Normal User is 0.6322078
# Euclidean distance from Root is 0.7802108
# Euclidean distance from Sumantra is 0.9057989
# Euclidean distance from Kunal is 1.1567186
# Euclidean distance from Normal User is 0.62955993
# Euclidean distance from Root is 0.77400935
# Euclidean distance from Sumantra is 0.9913694
# Euclidean distance from Kunal is 1.1558136
# Euclidean distance from Normal User is 0.71865565
# Euclidean distance from Root is 0.76100284
# Euclidean distance from Sumantra is 0.9943212
# Euclidean distance from Kunal is 1.0724571
# Euclidean distance from Normal User is 0.6027999
# Euclidean distance from Root is 0.725752
# Euclidean distance from Sumantra is 1.00165
# Euclidean distance from Kunal is 1.0500532
# Euclidean distance from Normal User is 0.5953375
# Euclidean distance from Root is 0.73587656
# Euclidean distance from Sumantra is 0.9876096
# Euclidean distance from Kunal is 1.1312381
# Euclidean distance from Normal User is 0.5705951
# Euclidean distance from Root is 0.6907736
# Euclidean distance from Sumantra is 1.0215435
# Euclidean distance from Kunal is 1.062352
# Euclidean distance from Normal User is 0.6263579
# Euclidean distance from Root is 0.69251496
# Euclidean distance from Sumantra is 1.0441755
# Euclidean distance from Kunal is 1.0465602
# Euclidean distance from Normal User is 0.5733103
# Euclidean distance from Root is 0.71025956
# Euclidean distance from Sumantra is 0.95488685
# Euclidean distance from Kunal is 1.0920347
# Euclidean distance from Normal User is 0.61610425
# Euclidean distance from Root is 0.7762352
# Euclidean distance from Sumantra is 0.9364152
# Euclidean distance from Kunal is 1.1020697
# Euclidean distance from Normal User is 0.55341184
# Euclidean distance from Root is 0.76051676
# Euclidean distance from Sumantra is 0.94623053
# Euclidean distance from Kunal is 1.186266
# Euclidean distance from Normal User is 0.6407122
# Euclidean distance from Root is 0.7152352
# Euclidean distance from Sumantra is 1.029217
# Euclidean distance from Kunal is 1.0635685
# Euclidean distance from Normal User is 0.63575494
# Euclidean distance from Root is 0.79747975
# Euclidean distance from Sumantra is 0.8474238
# Euclidean distance from Kunal is 1.1873254
# Euclidean distance from Normal User is 0.59361356
# Euclidean distance from Root is 0.71092397
# Euclidean distance from Sumantra is 1.0175117
# Euclidean distance from Kunal is 1.1510687
# Euclidean distance from Normal User is 0.5786699
# Euclidean distance from Root is 0.72512805
# Euclidean distance from Sumantra is 0.98719394
# Euclidean distance from Kunal is 1.1865557
# Euclidean distance from Normal User is 0.6476976
# Euclidean distance from Root is 0.7879008
# Euclidean distance from Sumantra is 0.86454827
# Euclidean distance from Kunal is 1.2359118
# Euclidean distance from Normal User is 0.59353644
# Euclidean distance from Root is 0.71303034
# Euclidean distance from Sumantra is 1.029267
# Euclidean distance from Kunal is 1.1951478
# Euclidean distance from Normal User is 0.6045903
# Euclidean distance from Root is 0.7508535
# Euclidean distance from Sumantra is 0.93643904
# Euclidean distance from Kunal is 1.1143434
# Euclidean distance from Normal User is 0.58906454
# Euclidean distance from Root is 0.7326327
# Euclidean distance from Sumantra is 0.92633426
# Euclidean distance from Kunal is 1.1724598
# Euclidean distance from Normal User is 0.60322034
# Euclidean distance from Root is 0.7364983
# Euclidean distance from Sumantra is 0.96691906
# Euclidean distance from Kunal is 1.2297989
# Euclidean distance from Normal User is 0.6820748
# Euclidean distance from Root is 0.80744195
# Euclidean distance from Sumantra is 0.90961295
# Euclidean distance from Kunal is 1.2036678
# Euclidean distance from Normal User is 0.6365857
# Euclidean distance from Root is 0.7387107
# Euclidean distance from Sumantra is 0.9848673
# Euclidean distance from Kunal is 1.171121
# Euclidean distance from Normal User is 0.6486893
# Euclidean distance from Root is 0.82871497
# Euclidean distance from Sumantra is 0.9275419
# Euclidean distance from Kunal is 1.2331958
# Euclidean distance from Normal User is 0.63245636
# Euclidean distance from Root is 0.7454293
# Euclidean distance from Sumantra is 0.9858423
# Euclidean distance from Kunal is 1.1187232
# Euclidean distance from Normal User is 0.6787367
# Euclidean distance from Root is 0.803475
# Euclidean distance from Sumantra is 0.89253443
# Euclidean distance from Kunal is 1.1400741
# Euclidean distance from Normal User is 0.7022792
# Euclidean distance from Root is 0.86871004
# Euclidean distance from Sumantra is 0.8567429
# Euclidean distance from Kunal is 1.1899197
# Euclidean distance from Normal User is 0.7044967
# Euclidean distance from Root is 0.85128665
# Euclidean distance from Sumantra is 0.86788774
# Euclidean distance from Kunal is 1.1084131
# Euclidean distance from Normal User is 0.7341047
# Euclidean distance from Root is 0.841108
# Euclidean distance from Sumantra is 0.88530415
# Euclidean distance from Kunal is 1.110771
# Euclidean distance from Normal User is 0.63061816
# Euclidean distance from Root is 0.81772876
# Euclidean distance from Sumantra is 0.8698775
# Euclidean distance from Kunal is 1.1351464
# Euclidean distance from Normal User is 0.67483264
# Euclidean distance from Root is 0.76039946
# Euclidean distance from Sumantra is 0.9295262
# Euclidean distance from Kunal is 1.1596918
# Euclidean distance from Normal User is 0.6785099
# Euclidean distance from Root is 0.8045663
# Euclidean distance from Sumantra is 0.94545376
# Euclidean distance from Kunal is 1.1896402
# Euclidean distance from Normal User is 0.6844157
# Euclidean distance from Root is 0.87548417
# Euclidean distance from Sumantra is 0.82774395
# Euclidean distance from Kunal is 1.2375891
# Euclidean distance from Normal User is 0.57021964
# Euclidean distance from Root is 0.7817811
# Euclidean distance from Sumantra is 0.9549778
# Euclidean distance from Kunal is 1.179411
# Euclidean distance from Normal User is 0.661769
# Euclidean distance from Root is 0.8626397
# Euclidean distance from Sumantra is 0.8194247
# Euclidean distance from Kunal is 1.1381092
# Euclidean distance from Normal User is 0.6945295
# Euclidean distance from Root is 0.8276484
# Euclidean distance from Sumantra is 0.92867047
# Euclidean distance from Kunal is 1.190514
# Euclidean distance from Normal User is 0.60571396
# Euclidean distance from Root is 0.6975525
# Euclidean distance from Sumantra is 1.0161985
# Euclidean distance from Kunal is 1.2070656
# Euclidean distance from Normal User is 0.6510915
# Euclidean distance from Root is 0.7710317
# Euclidean distance from Sumantra is 0.96422017
# Euclidean distance from Kunal is 1.1886963
# Euclidean distance from Normal User is 0.65937865
# Euclidean distance from Root is 0.826074
# Euclidean distance from Sumantra is 0.8558714
# Euclidean distance from Kunal is 1.188466
# Euclidean distance from Normal User is 0.6279885
# Euclidean distance from Root is 0.76481843
# Euclidean distance from Sumantra is 0.9042207
# Euclidean distance from Kunal is 1.1640542
# Euclidean distance from Normal User is 0.6527992
# Euclidean distance from Root is 0.75688404
# Euclidean distance from Sumantra is 0.88664305
# Euclidean distance from Kunal is 1.2652918
# Euclidean distance from Normal User is 0.6385725
# Euclidean distance from Root is 0.6709457
# Euclidean distance from Sumantra is 1.0878106
# Euclidean distance from Kunal is 1.142795
# Euclidean distance from Normal User is 0.6558904
# Euclidean distance from Root is 0.71300167
# Euclidean distance from Sumantra is 0.9447687
# Euclidean distance from Kunal is 1.160432
# Euclidean distance from Normal User is 0.6749157
# Euclidean distance from Root is 0.8177511
# Euclidean distance from Sumantra is 0.9421615
# Euclidean distance from Kunal is 1.0374677
# Euclidean distance from Normal User is 0.74626696
# Euclidean distance from Root is 0.8268784
# Euclidean distance from Sumantra is 0.9332098
# Euclidean distance from Kunal is 1.0427046
# Euclidean distance from Normal User is 0.7507892
# Euclidean distance from Root is 0.8755549
# Euclidean distance from Sumantra is 0.8695187
# Euclidean distance from Kunal is 1.1870574
# Euclidean distance from Normal User is 0.6158199
# Euclidean distance from Root is 0.7385705
# Euclidean distance from Sumantra is 0.963121
# Euclidean distance from Kunal is 1.2376133
# Euclidean distance from Normal User is 0.6387312
# Euclidean distance from Root is 0.7880486
# Euclidean distance from Sumantra is 0.9634038
# Euclidean distance from Kunal is 1.1144675
# Euclidean distance from Normal User is 0.6656534
# Euclidean distance from Root is 0.8259936
# Euclidean distance from Sumantra is 0.90887225
# Euclidean distance from Kunal is 1.1139144
# Euclidean distance from Normal User is 0.9342069
# Euclidean distance from Root is 1.1276037
# Euclidean distance from Sumantra is 0.99117666
# Euclidean distance from Kunal is 1.2106793
# Euclidean distance from Normal User is 0.6367241
# Euclidean distance from Root is 0.7966268
# Euclidean distance from Sumantra is 0.95507485
# Euclidean distance from Kunal is 1.2173915
# Euclidean distance from Normal User is 0.68934125
# Euclidean distance from Root is 0.57747394
# Euclidean distance from Sumantra is 1.1690547
# Euclidean distance from Kunal is 1.1281238
# Euclidean distance from Normal User is 0.8109021
# Euclidean distance from Root is 0.7262352
# Euclidean distance from Sumantra is 1.072693
# Euclidean distance from Kunal is 1.1561292
# Euclidean distance from Normal User is 0.9967594
# Euclidean distance from Root is 0.757173
# Euclidean distance from Sumantra is 1.2023202
# Euclidean distance from Kunal is 1.2917571
# Euclidean distance from Normal User is 0.9373122
# Euclidean distance from Root is 0.7492436
# Euclidean distance from Sumantra is 1.1926466
# Euclidean distance from Kunal is 1.2884085
# Euclidean distance from Normal User is 0.99501294
# Euclidean distance from Root is 0.77198696
# Euclidean distance from Sumantra is 1.2240033
# Euclidean distance from Kunal is 1.274791
# Euclidean distance from Normal User is 0.84615356
# Euclidean distance from Root is 0.6411812
# Euclidean distance from Sumantra is 1.1523359
# Euclidean distance from Kunal is 1.3345187
# Euclidean distance from Normal User is 0.98262763
# Euclidean distance from Root is 0.9053406
# Euclidean distance from Sumantra is 1.0458635
# Euclidean distance from Kunal is 1.1699504
# Euclidean distance from Normal User is 0.92672867
# Euclidean distance from Root is 0.80942065
# Euclidean distance from Sumantra is 1.0893593
# Euclidean distance from Kunal is 1.1065134
# Euclidean distance from Normal User is 0.69341373
# Euclidean distance from Root is 0.66590095
# Euclidean distance from Sumantra is 1.1112802
# Euclidean distance from Kunal is 1.0891126
# Euclidean distance from Normal User is 0.8436369
# Euclidean distance from Root is 0.8708443
# Euclidean distance from Sumantra is 0.998577
# Euclidean distance from Kunal is 1.135986
# Euclidean distance from Normal User is 0.85373056
# Euclidean distance from Root is 0.8607396
# Euclidean distance from Sumantra is 1.0123173
# Euclidean distance from Kunal is 1.1852232
# Euclidean distance from Normal User is 0.7462754
# Euclidean distance from Root is 0.7036442
# Euclidean distance from Sumantra is 1.1445853
# Euclidean distance from Kunal is 1.21045
# Euclidean distance from Normal User is 0.9116152
# Euclidean distance from Root is 0.86940503
# Euclidean distance from Sumantra is 1.0452839
# Euclidean distance from Kunal is 1.1895958
# Euclidean distance from Normal User is 0.78890157
# Euclidean distance from Root is 0.7047153
# Euclidean distance from Sumantra is 1.1877276
# Euclidean distance from Kunal is 1.1282897
# Euclidean distance from Normal User is 0.92189944
# Euclidean distance from Root is 0.9224583
# Euclidean distance from Sumantra is 0.95834064
# Euclidean distance from Kunal is 1.1648334
# Euclidean distance from Normal User is 0.8379116
# Euclidean distance from Root is 0.82658803
# Euclidean distance from Sumantra is 1.0041152
# Euclidean distance from Kunal is 1.1735915
# Euclidean distance from Normal User is 0.6667469
# Euclidean distance from Root is 0.57467115
# Euclidean distance from Sumantra is 1.0770632
# Euclidean distance from Kunal is 1.2879326
# Euclidean distance from Normal User is 0.9879766
# Euclidean distance from Root is 0.8418963
# Euclidean distance from Sumantra is 0.9832256
# Euclidean distance from Kunal is 1.3706965
# Euclidean distance from Normal User is 0.8432632
# Euclidean distance from Root is 0.6131606
# Euclidean distance from Sumantra is 1.1972992
# Euclidean distance from Kunal is 1.3099846
# Euclidean distance from Normal User is 0.8678314
# Euclidean distance from Root is 0.6353608
# Euclidean distance from Sumantra is 1.2061654
# Euclidean distance from Kunal is 1.1248037
# Euclidean distance from Normal User is 0.8401301
# Euclidean distance from Root is 0.7348067
# Euclidean distance from Sumantra is 1.0087341
# Euclidean distance from Kunal is 1.3136446
# Euclidean distance from Normal User is 0.9742271
# Euclidean distance from Root is 0.8059808
# Euclidean distance from Sumantra is 1.075953
# Euclidean distance from Kunal is 1.3811593
# Euclidean distance from Normal User is 0.9549974
# Euclidean distance from Root is 0.6833616
# Euclidean distance from Sumantra is 1.276986
# Euclidean distance from Kunal is 1.3888091
# Euclidean distance from Normal User is 0.99745053
# Euclidean distance from Root is 0.7098518
# Euclidean distance from Sumantra is 1.2824968
# Euclidean distance from Kunal is 1.2568992
# Euclidean distance from Normal User is 0.97319233
# Euclidean distance from Root is 0.69865245
# Euclidean distance from Sumantra is 1.1241144
# Euclidean distance from Kunal is 1.2866945
# Euclidean distance from Normal User is 0.9937723
# Euclidean distance from Root is 0.72264117
# Euclidean distance from Sumantra is 1.2097516
# Euclidean distance from Kunal is 1.2771019
# Euclidean distance from Normal User is 1.004019
# Euclidean distance from Root is 0.75288147
# Euclidean distance from Sumantra is 1.1655667
# Euclidean distance from Kunal is 1.1626424
# Euclidean distance from Normal User is 0.9250992
# Euclidean distance from Root is 0.8580098
# Euclidean distance from Sumantra is 0.9359372
# Euclidean distance from Kunal is 1.0795704
# Euclidean distance from Normal User is 0.8561336
# Euclidean distance from Root is 0.79337305
# Euclidean distance from Sumantra is 0.9936234
# Euclidean distance from Kunal is 1.1496938
# Euclidean distance from Normal User is 0.7373219
# Euclidean distance from Root is 0.59115565
# Euclidean distance from Sumantra is 1.0677823
# Euclidean distance from Kunal is 1.1333759
# Euclidean distance from Normal User is 0.80658954
# Euclidean distance from Root is 0.78481853
# Euclidean distance from Sumantra is 0.95032996
# Euclidean distance from Kunal is 1.0477326
# Euclidean distance from Normal User is 0.6793
# Euclidean distance from Root is 0.6389666
# Euclidean distance from Sumantra is 1.0253459
# Euclidean distance from Kunal is 1.0651906
# Euclidean distance from Normal User is 0.7831202
# Euclidean distance from Root is 0.7254407
# Euclidean distance from Sumantra is 0.9647273
# Euclidean distance from Kunal is 1.0676482
# Euclidean distance from Normal User is 0.68703645
# Euclidean distance from Root is 0.64647615
# Euclidean distance from Sumantra is 1.0747161
# Euclidean distance from Kunal is 1.1522182
# Euclidean distance from Normal User is 0.7943486
# Euclidean distance from Root is 0.83760875
# Euclidean distance from Sumantra is 0.8760851
# Euclidean distance from Kunal is 1.1025673
# Euclidean distance from Normal User is 0.77353126
# Euclidean distance from Root is 0.7759648
# Euclidean distance from Sumantra is 0.9408399
# Euclidean distance from Kunal is 1.0689812
# Euclidean distance from Normal User is 0.79846156
# Euclidean distance from Root is 0.76536405
# Euclidean distance from Sumantra is 0.9761099
# Euclidean distance from Kunal is 1.1034386
# Euclidean distance from Normal User is 0.775908
# Euclidean distance from Root is 0.76837194
# Euclidean distance from Sumantra is 0.98405653
# Euclidean distance from Kunal is 1.0580304
# Euclidean distance from Normal User is 0.7280142
# Euclidean distance from Root is 0.68860006
# Euclidean distance from Sumantra is 1.07785
# Euclidean distance from Kunal is 1.0670089
# Euclidean distance from Normal User is 0.71526676
# Euclidean distance from Root is 0.65047276
# Euclidean distance from Sumantra is 0.986676
# Euclidean distance from Kunal is 1.0757065
# Euclidean distance from Normal User is 0.94723994
# Euclidean distance from Root is 0.9329032
# Euclidean distance from Sumantra is 0.97263205
# Euclidean distance from Kunal is 1.1930646
# Euclidean distance from Normal User is 0.7713356
# Euclidean distance from Root is 0.7057206
# Euclidean distance from Sumantra is 1.0441886
# Euclidean distance from Kunal is 1.0516691
# Euclidean distance from Normal User is 0.8522823
# Euclidean distance from Root is 0.7676638
# Euclidean distance from Sumantra is 0.99853593
# Euclidean distance from Kunal is 1.1395632
# Euclidean distance from Normal User is 0.88159496
# Euclidean distance from Root is 0.84577507
# Euclidean distance from Sumantra is 0.9815421
# Euclidean distance from Kunal is 1.0842084
# Euclidean distance from Normal User is 0.7128949
# Euclidean distance from Root is 0.64383554
# Euclidean distance from Sumantra is 1.0118141
# Euclidean distance from Kunal is 1.0615458
# Euclidean distance from Normal User is 0.6694896
# Euclidean distance from Root is 0.6120346
# Euclidean distance from Sumantra is 1.0137323
# Euclidean distance from Kunal is 1.1155558
# Euclidean distance from Normal User is 0.8531897
# Euclidean distance from Root is 0.8718218
# Euclidean distance from Sumantra is 0.8750065
# Euclidean distance from Kunal is 1.0526943
# Euclidean distance from Normal User is 0.7467449
# Euclidean distance from Root is 0.7395943
# Euclidean distance from Sumantra is 1.0463573
# Euclidean distance from Kunal is 1.190643
# Euclidean distance from Normal User is 0.81744474
# Euclidean distance from Root is 0.74089956
# Euclidean distance from Sumantra is 1.0382208
# Euclidean distance from Kunal is 1.1529758
# Euclidean distance from Normal User is 0.6341358
# Euclidean distance from Root is 0.75151426
# Euclidean distance from Sumantra is 0.9280839
# Euclidean distance from Kunal is 1.2655096
# Euclidean distance from Normal User is 0.65107036
# Euclidean distance from Root is 0.811704
# Euclidean distance from Sumantra is 0.89609945
# Euclidean distance from Kunal is 1.2019447
# Euclidean distance from Normal User is 0.6048449
# Euclidean distance from Root is 0.7243834
# Euclidean distance from Sumantra is 0.8595469
# Euclidean distance from Kunal is 1.2782044
# Euclidean distance from Normal User is 0.6629673
# Euclidean distance from Root is 0.7512857
# Euclidean distance from Sumantra is 0.9540979
# Euclidean distance from Kunal is 1.237413
# Euclidean distance from Normal User is 0.6672955
# Euclidean distance from Root is 0.7834807
# Euclidean distance from Sumantra is 0.92010695
# Euclidean distance from Kunal is 1.2309675
# Euclidean distance from Normal User is 0.656938
# Euclidean distance from Root is 0.8275735
# Euclidean distance from Sumantra is 0.93503255
# Euclidean distance from Kunal is 1.217205
# Euclidean distance from Normal User is 0.680092
# Euclidean distance from Root is 0.801679
# Euclidean distance from Sumantra is 0.84184647
# Euclidean distance from Kunal is 1.2630339
# Euclidean distance from Normal User is 0.6737569
# Euclidean distance from Root is 0.8002305
# Euclidean distance from Sumantra is 0.9826502
# Euclidean distance from Kunal is 1.0712869
# Euclidean distance from Normal User is 0.658857
# Euclidean distance from Root is 0.8055525
# Euclidean distance from Sumantra is 0.9358171
# Euclidean distance from Kunal is 1.044857
# Euclidean distance from Normal User is 0.7380063
# Euclidean distance from Root is 0.9011576
# Euclidean distance from Sumantra is 0.89158404
# Euclidean distance from Kunal is 1.0847776
# Euclidean distance from Normal User is 0.60833263
# Euclidean distance from Root is 0.7023359
# Euclidean distance from Sumantra is 0.8975807
# Euclidean distance from Kunal is 1.281682
# Euclidean distance from Normal User is 0.8436767
# Euclidean distance from Root is 0.8343451
# Euclidean distance from Sumantra is 0.9430877
# Euclidean distance from Kunal is 1.215451
# Euclidean distance from Normal User is 0.6149993
# Euclidean distance from Root is 0.64979315
# Euclidean distance from Sumantra is 1.0942098
# Euclidean distance from Kunal is 1.2194428
# Euclidean distance from Normal User is 0.7384221
# Euclidean distance from Root is 0.6723495
# Euclidean distance from Sumantra is 1.1674701
# Euclidean distance from Kunal is 1.2269561
# Euclidean distance from Normal User is 0.8645876
# Euclidean distance from Root is 0.86404073
# Euclidean distance from Sumantra is 0.9612448
# Euclidean distance from Kunal is 1.1324706
# Euclidean distance from Normal User is 0.7635085
# Euclidean distance from Root is 0.8541852
# Euclidean distance from Sumantra is 0.8903681
# Euclidean distance from Kunal is 0.9890108
# Euclidean distance from Normal User is 0.54246974
# Euclidean distance from Root is 0.7855009
# Euclidean distance from Sumantra is 0.9513912
# Euclidean distance from Kunal is 1.0614187
# Euclidean distance from Normal User is 0.68873566
# Euclidean distance from Root is 0.8830194
# Euclidean distance from Sumantra is 0.8026925
# Euclidean distance from Kunal is 1.0476154
# Euclidean distance from Normal User is 0.6165074
# Euclidean distance from Root is 0.8343959
# Euclidean distance from Sumantra is 0.8999555
# Euclidean distance from Kunal is 1.0725249
# Euclidean distance from Normal User is 0.64844203
# Euclidean distance from Root is 0.88099074
# Euclidean distance from Sumantra is 0.844617
# Euclidean distance from Kunal is 1.1135901
# Euclidean distance from Normal User is 0.7501221
# Euclidean distance from Root is 0.8163031
# Euclidean distance from Sumantra is 0.88986534
# Euclidean distance from Kunal is 1.0790511
# Euclidean distance from Normal User is 0.7589138
# Euclidean distance from Root is 0.8545866
# Euclidean distance from Sumantra is 0.87054956
# Euclidean distance from Kunal is 1.0067751
# Euclidean distance from Normal User is 0.70168704
# Euclidean distance from Root is 0.84294593
# Euclidean distance from Sumantra is 0.9199933
# Euclidean distance from Kunal is 1.0722849
# Euclidean distance from Normal User is 0.5102402
# Euclidean distance from Root is 0.7679693
# Euclidean distance from Sumantra is 0.9022329
# Euclidean distance from Kunal is 1.2318318
# Euclidean distance from Normal User is 0.6550539
# Euclidean distance from Root is 0.69963217
# Euclidean distance from Sumantra is 1.015671
# Euclidean distance from Kunal is 1.2423724
# Euclidean distance from Normal User is 0.6507308
# Euclidean distance from Root is 0.8465444
# Euclidean distance from Sumantra is 0.8675796
# Euclidean distance from Kunal is 1.2108893
# Euclidean distance from Normal User is 0.5437457
# Euclidean distance from Root is 0.7609646
# Euclidean distance from Sumantra is 0.9301468
# Euclidean distance from Kunal is 1.1471174
# Euclidean distance from Normal User is 0.51690036
# Euclidean distance from Root is 0.69535357
# Euclidean distance from Sumantra is 0.97791183
# Euclidean distance from Kunal is 1.1388469
# Euclidean distance from Normal User is 0.4457999
# Euclidean distance from Root is 0.7399993
# Euclidean distance from Sumantra is 0.92124957
# Euclidean distance from Kunal is 1.1223484
# Euclidean distance from Normal User is 0.5406
# Euclidean distance from Root is 0.72253865
# Euclidean distance from Sumantra is 1.0122801
# Euclidean distance from Kunal is 1.1516653
# Euclidean distance from Normal User is 0.5248239
# Euclidean distance from Root is 0.7063544
# Euclidean distance from Sumantra is 1.027026
# Euclidean distance from Kunal is 1.2289438
# Euclidean distance from Normal User is 0.67078865
# Euclidean distance from Root is 0.7283828
# Euclidean distance from Sumantra is 1.0833067
# Euclidean distance from Kunal is 1.0548043
# Euclidean distance from Normal User is 0.69020003
# Euclidean distance from Root is 0.7853923
# Euclidean distance from Sumantra is 0.97506005
# Euclidean distance from Kunal is 1.0491495
# Euclidean distance from Normal User is 0.69528806
# Euclidean distance from Root is 0.82953006
# Euclidean distance from Sumantra is 0.9034931
# Euclidean distance from Kunal is 0.96174085
# Euclidean distance from Normal User is 0.6198278
# Euclidean distance from Root is 0.80563086
# Euclidean distance from Sumantra is 0.89913213
# Euclidean distance from Kunal is 1.043053
# Euclidean distance from Normal User is 0.6618666
# Euclidean distance from Root is 0.9185427
# Euclidean distance from Sumantra is 0.8922779
# Euclidean distance from Kunal is 1.2060082
# Euclidean distance from Normal User is 0.7132061
# Euclidean distance from Root is 0.85683924
# Euclidean distance from Sumantra is 0.95200443
# Euclidean distance from Kunal is 1.1056374
# Euclidean distance from Normal User is 0.649949
# Euclidean distance from Root is 0.91787237
# Euclidean distance from Sumantra is 0.8656366
# Euclidean distance from Kunal is 1.1115539
# Euclidean distance from Normal User is 0.67378855
# Euclidean distance from Root is 0.9079178
# Euclidean distance from Sumantra is 0.8653136
# Euclidean distance from Kunal is 1.1146666
# Euclidean distance from Normal User is 0.6443644
# Euclidean distance from Root is 0.8381773
# Euclidean distance from Sumantra is 0.91321266
# Euclidean distance from Kunal is 0.98710364
# Euclidean distance from Normal User is 0.59349585
# Euclidean distance from Root is 0.81061983
# Euclidean distance from Sumantra is 0.9239663
# Euclidean distance from Kunal is 1.0235213
# Euclidean distance from Normal User is 0.72618604
# Euclidean distance from Root is 0.85876006
# Euclidean distance from Sumantra is 0.93479633
# Euclidean distance from Kunal is 1.2750365
# Euclidean distance from Normal User is 0.78615123
# Euclidean distance from Root is 0.72539437
# Euclidean distance from Sumantra is 1.1166626
# Euclidean distance from Kunal is 1.2355168
# Euclidean distance from Normal User is 0.66656864
# Euclidean distance from Root is 0.7568218
# Euclidean distance from Sumantra is 1.0407578
# Euclidean distance from Kunal is 1.165867
# Euclidean distance from Normal User is 0.70819515
# Euclidean distance from Root is 0.7460419
# Euclidean distance from Sumantra is 1.0376879
# Euclidean distance from Kunal is 1.2111169
# Euclidean distance from Normal User is 0.6718696
# Euclidean distance from Root is 0.68239397
# Euclidean distance from Sumantra is 1.1329027
# Euclidean distance from Kunal is 1.250448
# Euclidean distance from Normal User is 0.62023187
# Euclidean distance from Root is 0.668406
# Euclidean distance from Sumantra is 1.0793084
# Euclidean distance from Kunal is 1.2052397
# Euclidean distance from Normal User is 0.6041692
# Euclidean distance from Root is 0.634613
# Euclidean distance from Sumantra is 1.0998973
# Euclidean distance from Kunal is 1.1358278
# Euclidean distance from Normal User is 0.5334295
# Euclidean distance from Root is 0.63106
# Euclidean distance from Sumantra is 1.0602678
# Euclidean distance from Kunal is 1.1993251
# Euclidean distance from Normal User is 0.6397238
# Euclidean distance from Root is 0.7295644
# Euclidean distance from Sumantra is 1.0885204
# Euclidean distance from Kunal is 1.1685284
# Euclidean distance from Normal User is 0.55922115
# Euclidean distance from Root is 0.6287683
# Euclidean distance from Sumantra is 1.0661303
# Euclidean distance from Kunal is 1.2772744
# Euclidean distance from Normal User is 0.5839382
# Euclidean distance from Root is 0.6474441
# Euclidean distance from Sumantra is 1.0788602
# Euclidean distance from Kunal is 1.1991323
# Euclidean distance from Normal User is 0.6050289
# Euclidean distance from Root is 0.723064
# Euclidean distance from Sumantra is 1.0292307
# Euclidean distance from Kunal is 1.1176053
# Euclidean distance from Normal User is 0.66954017
# Euclidean distance from Root is 0.79618186
# Euclidean distance from Sumantra is 0.98990583
# Euclidean distance from Kunal is 1.2995825
# Euclidean distance from Normal User is 0.6717026
# Euclidean distance from Root is 0.6727298
# Euclidean distance from Sumantra is 1.0488658
# Euclidean distance from Kunal is 1.1498072
# Euclidean distance from Normal User is 0.75760126
# Euclidean distance from Root is 0.7888077
# Euclidean distance from Sumantra is 0.9508475
# Euclidean distance from Kunal is 1.0199611
# Euclidean distance from Normal User is 0.93843466
# Euclidean distance from Root is 0.9058164
# Euclidean distance from Sumantra is 0.86571383
# Euclidean distance from Kunal is 1.0716373
# Euclidean distance from Normal User is 0.61043346
# Euclidean distance from Root is 0.8106169
# Euclidean distance from Sumantra is 0.87353265
# Euclidean distance from Kunal is 0.97268414
# Euclidean distance from Normal User is 0.5737163
# Euclidean distance from Root is 0.73985875
# Euclidean distance from Sumantra is 0.9791765
# Euclidean distance from Kunal is 1.1274081
# Euclidean distance from Normal User is 0.6796729
# Euclidean distance from Root is 0.8876961
# Euclidean distance from Sumantra is 0.8901839
# Euclidean distance from Kunal is 1.1576706
# Euclidean distance from Normal User is 0.7621417
# Euclidean distance from Root is 0.9608486
# Euclidean distance from Sumantra is 0.8310519
# Euclidean distance from Kunal is 1.1765949
# Euclidean distance from Normal User is 0.6177187
# Euclidean distance from Root is 0.7654923
# Euclidean distance from Sumantra is 0.91052735
# Euclidean distance from Kunal is 1.3204736
# Euclidean distance from Normal User is 0.71349204
# Euclidean distance from Root is 0.7288891
# Euclidean distance from Sumantra is 1.0065626
# Euclidean distance from Kunal is 1.2361859
# Euclidean distance from Normal User is 0.6903577
# Euclidean distance from Root is 0.8179971
# Euclidean distance from Sumantra is 0.86908746
# Euclidean distance from Kunal is 1.2917645
# Euclidean distance from Normal User is 0.74784654
# Euclidean distance from Root is 0.80191296
# Euclidean distance from Sumantra is 0.9325368
# Euclidean distance from Kunal is 1.2319714
# Euclidean distance from Normal User is 0.68355
# Euclidean distance from Root is 0.81984395
# Euclidean distance from Sumantra is 0.9151445
# Euclidean distance from Kunal is 1.3018457
# Euclidean distance from Normal User is 0.7152771
# Euclidean distance from Root is 0.73263264
# Euclidean distance from Sumantra is 1.1189967
# Euclidean distance from Kunal is 1.2297443
# Euclidean distance from Normal User is 0.64620465
# Euclidean distance from Root is 0.64770377
# Euclidean distance from Sumantra is 1.0649807
# Euclidean distance from Kunal is 1.1409527
# Euclidean distance from Normal User is 0.63275945
# Euclidean distance from Root is 0.7960104
# Euclidean distance from Sumantra is 0.887282
# Euclidean distance from Kunal is 1.194887
# Euclidean distance from Normal User is 0.70900655
# Euclidean distance from Root is 0.8346693
# Euclidean distance from Sumantra is 0.87098914
# Euclidean distance from Kunal is 1.1350546
# Euclidean distance from Normal User is 0.64484644
# Euclidean distance from Root is 0.739452
# Euclidean distance from Sumantra is 0.9337327
# Euclidean distance from Kunal is 1.1168051
# Euclidean distance from Normal User is 0.59199905
# Euclidean distance from Root is 0.7167646
# Euclidean distance from Sumantra is 0.9412206
# Euclidean distance from Kunal is 1.2470273
# Euclidean distance from Normal User is 0.73993444
# Euclidean distance from Root is 0.8337884
# Euclidean distance from Sumantra is 0.9099813
# Euclidean distance from Kunal is 1.1486224
# Euclidean distance from Normal User is 0.66851777
# Euclidean distance from Root is 0.78999287
# Euclidean distance from Sumantra is 0.9024531
# Euclidean distance from Kunal is 1.1968278
# Euclidean distance from Normal User is 0.71835357
# Euclidean distance from Root is 0.87636214
# Euclidean distance from Sumantra is 0.844697
# Euclidean distance from Kunal is 1.1618191
# Euclidean distance from Normal User is 0.6913502
# Euclidean distance from Root is 0.8349181
# Euclidean distance from Sumantra is 0.8996342
# Euclidean distance from Kunal is 1.1953497
# Euclidean distance from Normal User is 0.7006859
# Euclidean distance from Root is 0.89079684
# Euclidean distance from Sumantra is 0.90058607
# Euclidean distance from Kunal is 1.2552686
# Euclidean distance from Normal User is 0.76412946
# Euclidean distance from Root is 0.85783535
# Euclidean distance from Sumantra is 0.90809923
# Euclidean distance from Kunal is 1.1006427
# Euclidean distance from Normal User is 0.7590977
# ...
# Euclidean distance from Sumantra is 0.84631926
# Euclidean distance from Kunal is 1.1136806
# Euclidean distance from Normal User is 0.709121
# Euclidean distance from Root is 0.8451663
# Euclidean distance from Sumantra is 0.86015075
# Euclidean distance from Kunal is 1.0839542
# Euclidean distance from Normal User is 0.7897437
# Euclidean distance from Root is 0.9012962
# Euclidean distance from Sumantra is 0.8604456
# Euclidean distance from Kunal is 1.0850366
# Euclidean distance from Normal User is 0.81391126
# Euclidean distance from Root is 0.8995831
# Euclidean distance from Sumantra is 0.83884495
# Euclidean distance from Kunal is 1.1665541
# Euclidean distance from Normal User is 0.8076504
# Euclidean distance from Root is 0.89985603
# Euclidean distance from Sumantra is 0.82752687
# Euclidean distance from Kunal is 1.0406255
# Euclidean distance from Normal User is 0.68122816
# Euclidean distance from Root is 0.79145956
# Euclidean distance from Sumantra is 0.9249267
# Euclidean distance from Kunal is 0.9651108
# Euclidean distance from Normal User is 0.73058796
# Euclidean distance from Root is 0.76015955
# Euclidean distance from Sumantra is 0.94460446
# Euclidean distance from Kunal is 1.0122665
# Euclidean distance from Normal User is 0.7525155
# Euclidean distance from Root is 0.86939037
# Euclidean distance from Sumantra is 0.94248146
# Euclidean distance from Kunal is 1.120894
# Euclidean distance from Normal User is 0.7234834
# Euclidean distance from Root is 0.844966
# Euclidean distance from Sumantra is 0.8245924
# Euclidean distance from Kunal is 1.0263091
# Euclidean distance from Normal User is 0.7009689
# Euclidean distance from Root is 0.7743839
# Euclidean distance from Sumantra is 0.99247825
# Euclidean distance from Kunal is 1.0709816
# Euclidean distance from Normal User is 0.6774493
# Euclidean distance from Root is 0.7422804
# Euclidean distance from Sumantra is 0.9455966
# Euclidean distance from Kunal is 1.0547832
# Euclidean distance from Normal User is 0.68121964
# Euclidean distance from Root is 0.79475677
# Euclidean distance from Sumantra is 0.9126273
# Euclidean distance from Kunal is 1.0036881
# Euclidean distance from Normal User is 0.6906205
# Euclidean distance from Root is 0.81283087
# Euclidean distance from Sumantra is 0.9212552
# Euclidean distance from Kunal is 1.0658212
# Euclidean distance from Normal User is 0.7017682
# Euclidean distance from Root is 0.84803736
# Euclidean distance from Sumantra is 0.9924383
# Euclidean distance from Kunal is 1.060306
# Euclidean distance from Normal User is 0.7355469
# Euclidean distance from Root is 0.83085316
# Euclidean distance from Sumantra is 0.950502
# Euclidean distance from Kunal is 1.1008978
# Euclidean distance from Normal User is 0.70932037
# Euclidean distance from Root is 0.8502117
# Euclidean distance from Sumantra is 0.87481445
# Euclidean distance from Kunal is 1.0669091
# Euclidean distance from Normal User is 0.72302234
# Euclidean distance from Root is 0.8375592
# Euclidean distance from Sumantra is 0.9416759
# Euclidean distance from Kunal is 1.0305696
# Euclidean distance from Normal User is 0.7673916
# Euclidean distance from Root is 0.8449466
# Euclidean distance from Sumantra is 0.95269525
# Euclidean distance from Kunal is 1.0113308
# Euclidean distance from Normal User is 0.753033
# Euclidean distance from Root is 0.84852993
# Euclidean distance from Sumantra is 0.92245084
# Euclidean distance from Kunal is 1.023628
# Euclidean distance from Normal User is 0.7072382
# Euclidean distance from Root is 0.80786824
# Euclidean distance from Sumantra is 0.98966366
# Euclidean distance from Kunal is 1.0453343
# Euclidean distance from Normal User is 0.7025648
# Euclidean distance from Root is 0.8470572
# Euclidean distance from Sumantra is 0.94505334
# Euclidean distance from Kunal is 1.1227943
# Euclidean distance from Normal User is 0.73059195
# Euclidean distance from Root is 0.89410275
# Euclidean distance from Sumantra is 0.98805416
# Euclidean distance from Kunal is 1.0058078
# Euclidean distance from Normal User is 0.7826045
# Euclidean distance from Root is 0.8575332
# Euclidean distance from Sumantra is 0.92834187
# Euclidean distance from Kunal is 1.0413775
# Euclidean distance from Normal User is 0.7389884
# Euclidean distance from Root is 0.89150083
# Euclidean distance from Sumantra is 0.8812137
# Euclidean distance from Kunal is 1.101392
# Euclidean distance from Normal User is 0.6282835
# Euclidean distance from Root is 0.6967171
# Euclidean distance from Sumantra is 0.9430015
# Euclidean distance from Kunal is 1.1959492
# Euclidean distance from Normal User is 0.57326967
# Euclidean distance from Root is 0.6631353
# Euclidean distance from Sumantra is 0.980774
# Euclidean distance from Kunal is 1.098517
# Euclidean distance from Normal User is 0.6197686
# Euclidean distance from Root is 0.64355356
# Euclidean distance from Sumantra is 1.0401108
# Euclidean distance from Kunal is 1.0745414
# Euclidean distance from Normal User is 0.72544444
# Euclidean distance from Root is 0.8000448
# Euclidean distance from Sumantra is 0.91902214
# Euclidean distance from Kunal is 1.0964676
# Euclidean distance from Normal User is 0.6778377
# Euclidean distance from Root is 0.77794576
# Euclidean distance from Sumantra is 0.9132685
# Euclidean distance from Kunal is 1.063777
# Euclidean distance from Normal User is 0.7033536
# Euclidean distance from Root is 0.78115106
# Euclidean distance from Sumantra is 0.9343799
# Euclidean distance from Kunal is 1.0042146
# Euclidean distance from Normal User is 0.65052634
# Euclidean distance from Root is 0.721538
# Euclidean distance from Sumantra is 0.9876146
# Euclidean distance from Kunal is 1.0750859
# Euclidean distance from Normal User is 0.6685664
# Euclidean distance from Root is 0.81304276
# Euclidean distance from Sumantra is 0.8533077
# Euclidean distance from Kunal is 1.114205
# Euclidean distance from Normal User is 0.78331333
# Euclidean distance from Root is 0.8936388
# Euclidean distance from Sumantra is 0.78196335
# Euclidean distance from Kunal is 1.1650134
# Euclidean distance from Normal User is 0.6240294
# Euclidean distance from Root is 0.6576819
# Euclidean distance from Sumantra is 1.0937428
# Euclidean distance from Kunal is 1.0397341
# Euclidean distance from Normal User is 0.650269
# Euclidean distance from Root is 0.68680745
# Euclidean distance from Sumantra is 0.98863316
# Euclidean distance from Kunal is 0.9535237
# Euclidean distance from Normal User is 0.750887
# Euclidean distance from Root is 0.834255
# Euclidean distance from Sumantra is 0.8801249
# Euclidean distance from Kunal is 0.9954619
# Euclidean distance from Normal User is 0.7704092
# Euclidean distance from Root is 0.91233754
# Euclidean distance from Sumantra is 0.81846964
# Euclidean distance from Kunal is 1.0055778
# Euclidean distance from Normal User is 0.617805
# Euclidean distance from Root is 0.7437062
# Euclidean distance from Sumantra is 0.95265895
# Euclidean distance from Kunal is 1.1323018
# Euclidean distance from Normal User is 0.6270313
# Euclidean distance from Root is 0.6220951
# Euclidean distance from Sumantra is 1.0937467
# Euclidean distance from Kunal is 1.1017962
# Euclidean distance from Normal User is 0.68105763
# Euclidean distance from Root is 0.77809876
# Euclidean distance from Sumantra is 0.8877897
# Euclidean distance from Kunal is 1.0501969
# Euclidean distance from Normal User is 0.6001612
# Euclidean distance from Root is 0.7148931
# Euclidean distance from Sumantra is 1.0003656
# Euclidean distance from Kunal is 1.0585002
# Euclidean distance from Normal User is 0.6684445
# Euclidean distance from Root is 0.73675835
# Euclidean distance from Sumantra is 0.94858474
# Euclidean distance from Kunal is 1.0771043
# Euclidean distance from Normal User is 0.600684
# Euclidean distance from Root is 0.7493725
# Euclidean distance from Sumantra is 0.94863355
# Euclidean distance from Kunal is 1.098346
# Euclidean distance from Normal User is 0.5998496
# Euclidean distance from Root is 0.73492324
# Euclidean distance from Sumantra is 1.0554856
# Euclidean distance from Kunal is 1.1069413
# Euclidean distance from Normal User is 0.5673318
# Euclidean distance from Root is 0.7056578
# Euclidean distance from Sumantra is 0.9488895
# Euclidean distance from Kunal is 1.0815719
# Euclidean distance from Normal User is 0.5772104
# Euclidean distance from Root is 0.67170405
# Euclidean distance from Sumantra is 1.0402409
# Euclidean distance from Kunal is 1.1435649
# Euclidean distance from Normal User is 0.6685961
# Euclidean distance from Root is 0.7454103
# Euclidean distance from Sumantra is 1.101455
# Euclidean distance from Kunal is 1.0311131
# Euclidean distance from Normal User is 0.61414194
# Euclidean distance from Root is 0.7560795
# Euclidean distance from Sumantra is 1.0218884
# Euclidean distance from Kunal is 1.0191942
# Euclidean distance from Normal User is 0.5987839
# Euclidean distance from Root is 0.7401601
# Euclidean distance from Sumantra is 0.9849834
# Euclidean distance from Kunal is 1.1672262
# Euclidean distance from Normal User is 0.56161565
# Euclidean distance from Root is 0.6174675
# Euclidean distance from Sumantra is 1.037755
# Euclidean distance from Kunal is 1.1551079
# Euclidean distance from Normal User is 0.578773
# Euclidean distance from Root is 0.72988826
# Euclidean distance from Sumantra is 0.9467596
# Euclidean distance from Kunal is 1.1408516
# Euclidean distance from Normal User is 0.62871367
# Euclidean distance from Root is 0.7762792
# Euclidean distance from Sumantra is 0.91574544
# Euclidean distance from Kunal is 1.2215374
# Euclidean distance from Normal User is 0.7277663
# Euclidean distance from Root is 0.8317256
# Euclidean distance from Sumantra is 0.93764913
# Euclidean distance from Kunal is 1.1284386
# Euclidean distance from Normal User is 0.7317888
# Euclidean distance from Root is 0.7734516
# Euclidean distance from Sumantra is 0.9635481
# Euclidean distance from Kunal is 1.169112
# Euclidean distance from Normal User is 0.7749507
# Euclidean distance from Root is 0.8918348
# Euclidean distance from Sumantra is 0.81189376
# Euclidean distance from Kunal is 1.3184544
# Euclidean distance from Normal User is 0.7034512
# Euclidean distance from Root is 0.7802915
# Euclidean distance from Sumantra is 0.9611782
# Euclidean distance from Kunal is 1.11836
# Euclidean distance from Normal User is 0.70114976
# Euclidean distance from Root is 0.7783389
# Euclidean distance from Sumantra is 0.94403744
# Euclidean distance from Kunal is 1.2176738
# Euclidean distance from Normal User is 0.7728972
# Euclidean distance from Root is 0.68651986
# Euclidean distance from Sumantra is 1.0571247
# Euclidean distance from Kunal is 1.2722358
# Euclidean distance from Normal User is 0.76720256
# Euclidean distance from Root is 0.7279725
# Euclidean distance from Sumantra is 1.0382881
# Euclidean distance from Kunal is 1.0430305
# Euclidean distance from Normal User is 0.7188824
# Euclidean distance from Root is 0.86937165
# Euclidean distance from Sumantra is 0.8840014
# Euclidean distance from Kunal is 1.0422338
# Euclidean distance from Normal User is 0.7097464
# Euclidean distance from Root is 0.8385121
# Euclidean distance from Sumantra is 0.86465883
# Euclidean distance from Kunal is 1.0918816
# Euclidean distance from Normal User is 0.61022294
# Euclidean distance from Root is 0.67600524
# Euclidean distance from Sumantra is 0.9461137
# Euclidean distance from Kunal is 0.97173154
# Euclidean distance from Normal User is 0.6642852
# Euclidean distance from Root is 0.7341019
# Euclidean distance from Sumantra is 0.94754076
# Euclidean distance from Kunal is 1.0741407
# Euclidean distance from Normal User is 0.6637956
# Euclidean distance from Root is 0.7188564
# Euclidean distance from Sumantra is 0.99937534
# Euclidean distance from Kunal is 1.1986109
# Euclidean distance from Normal User is 0.7388099
# Euclidean distance from Root is 0.8973946
# Euclidean distance from Sumantra is 0.7340911
# Euclidean distance from Kunal is 1.0955849
# Euclidean distance from Normal User is 0.60986006
# Euclidean distance from Root is 0.71727586
# Euclidean distance from Sumantra is 0.9374774
# Euclidean distance from Kunal is 1.0947629
# Euclidean distance from Normal User is 0.60070807
# Euclidean distance from Root is 0.6908888
# Euclidean distance from Sumantra is 0.97014695
# Euclidean distance from Kunal is 1.0230073
# Euclidean distance from Normal User is 0.67581123
# Euclidean distance from Root is 0.6949565
# Euclidean distance from Sumantra is 0.98514473
# Euclidean distance from Kunal is 0.9848838
# Euclidean distance from Normal User is 0.627797
# Euclidean distance from Root is 0.76903075
# Euclidean distance from Sumantra is 0.9599216
# Euclidean distance from Kunal is 1.0035098
# Euclidean distance from Normal User is 0.6352742
# Euclidean distance from Root is 0.71627426
# Euclidean distance from Sumantra is 0.99432355
# Euclidean distance from Kunal is 1.080489
# Euclidean distance from Normal User is 0.6406751
# Euclidean distance from Root is 0.7511858
# Euclidean distance from Sumantra is 0.867396
# Euclidean distance from Kunal is 1.0710738
# Euclidean distance from Normal User is 0.67513263
# Euclidean distance from Root is 0.76751894
# Euclidean distance from Sumantra is 0.8959253
# Euclidean distance from Kunal is 1.1526347
# Euclidean distance from Normal User is 0.53686816
# Euclidean distance from Root is 0.61541474
# Euclidean distance from Sumantra is 1.0064626
# Euclidean distance from Kunal is 1.1306192
# Euclidean distance from Normal User is 0.6124976
# Euclidean distance from Root is 0.7480317
# Euclidean distance from Sumantra is 0.90356696
# Euclidean distance from Kunal is 1.1460971
# Euclidean distance from Normal User is 0.6978857
# Euclidean distance from Root is 0.8068108
# Euclidean distance from Sumantra is 0.8503121
# Euclidean distance from Kunal is 1.0965785
# Euclidean distance from Normal User is 0.61511993
# Euclidean distance from Root is 0.80221313
# Euclidean distance from Sumantra is 0.86050713
# Euclidean distance from Kunal is 1.1073759
# Euclidean distance from Normal User is 0.5768942
# Euclidean distance from Root is 0.7516457
# Euclidean distance from Sumantra is 0.9114356
# Euclidean distance from Kunal is 1.1089474
# Euclidean distance from Normal User is 0.65117794
# Euclidean distance from Root is 0.7883224
# Euclidean distance from Sumantra is 0.82175153
# Euclidean distance from Kunal is 1.1937692
# Euclidean distance from Normal User is 0.64132077
# Euclidean distance from Root is 0.794484
# Euclidean distance from Sumantra is 0.86250687
# Euclidean distance from Kunal is 1.1015438
# Euclidean distance from Normal User is 0.62548286
# Euclidean distance from Root is 0.8186192
# Euclidean distance from Sumantra is 0.8460507
# Euclidean distance from Kunal is 1.081954
# Euclidean distance from Normal User is 0.57115555
# Euclidean distance from Root is 0.7765803
# Euclidean distance from Sumantra is 0.89690834
# Euclidean distance from Kunal is 1.1023169
# Euclidean distance from Normal User is 0.6609402
# Euclidean distance from Root is 0.83544356
# Euclidean distance from Sumantra is 0.8200857
# Euclidean distance from Kunal is 1.1660991
# Euclidean distance from Normal User is 0.60936296
# Euclidean distance from Root is 0.827228
# Euclidean distance from Sumantra is 0.8052802
# Euclidean distance from Kunal is 1.1245085
# Euclidean distance from Normal User is 0.5768786
# Euclidean distance from Root is 0.70242935
# Euclidean distance from Sumantra is 0.89995307
# Euclidean distance from Kunal is 1.1003163
# Euclidean distance from Normal User is 0.7099209
# Euclidean distance from Root is 0.8072967
# Euclidean distance from Sumantra is 0.8981878
# Euclidean distance from Kunal is 1.2249104
# Euclidean distance from Normal User is 0.65178347
# Euclidean distance from Root is 0.7335122
# Euclidean distance from Sumantra is 0.93989867
# Euclidean distance from Kunal is 1.2433407
# Euclidean distance from Normal User is 0.57974714
# Euclidean distance from Root is 0.72799784
# Euclidean distance from Sumantra is 0.958998
# Euclidean distance from Kunal is 1.2056087
# Euclidean distance from Normal User is 0.83712184
# Euclidean distance from Root is 0.8602096
# Euclidean distance from Sumantra is 0.9564208
# Euclidean distance from Kunal is 1.1779288
# Euclidean distance from Normal User is 0.8633628
# Euclidean distance from Root is 0.94971156
# Euclidean distance from Sumantra is 0.91312146
